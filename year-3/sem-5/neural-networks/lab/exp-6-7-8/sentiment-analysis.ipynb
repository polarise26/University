# %% [markdown]
# #### Importing Dependencies:

# %%
import numpy as np 
import pandas as pd 
import keras
import tensorflow as tf
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re

# %% [markdown]
# #### Data Cleaning:

# %%
df = pd.read_csv('twtData.csv')
df.head(5)
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# 0                     1.0000            NaN  ...              NaN
# 1                     1.0000            NaN  ...              NaN
# 2                     0.6629            NaN  ...              NaN
# 3                     0.7039            NaN  ...              NaN
# 4                     1.0000            NaN  ...              NaN
#
#   retweet_count  sentiment_gold subject_matter_gold  \
# 0             5             NaN                 NaN
# 1            26             NaN                 NaN
# 2            27             NaN                 NaN
# 3           138             NaN                 NaN
# 4           156             NaN                 NaN
#
#                                                 text tweet_coord  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2  RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3  RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
#
#                tweet_created            tweet_id  tweet_location  \
# 0  2015-08-07 09:54:46 -0700  629697200650592256             NaN
# 1  2015-08-07 09:54:46 -0700  629697199560069120             NaN
# 2  2015-08-07 09:54:46 -0700  629697199312482304             NaN
# 3  2015-08-07 09:54:45 -0700  629697197118861312           Texas
# 4  2015-08-07 09:54:45 -0700  629697196967903232             NaN
#
#                 user_timezone
# 0                       Quito
# 1                         NaN
# 2                         NaN
# 3  Central Time (US & Canada)
# 4                     Arizona
#
# [5 rows x 21 columns]

# %% [markdown]
# Only keeping relevant columns, and removing RT from the tweets that are retweets.

# %%
df = df[['text','sentiment']]

df['text'] = df['text'].apply(lambda x: x.lower())
df['text'] = df['text'].apply((lambda x: re.sub('[^a-zA-z0-9\s]', '', x)))

# %%
for idx, row in df.iterrows():
    row[0] = row[0].replace('rt', ' ')

df.head()
# Out:
#                                                 text sentiment
# 1    scottwalker didnt catch the full gopdebate l...  Positive
# 3    robgeorge that carly fiorina is trending  ho...  Positive
# 4    danscavino gopdebate w realdonaldtrump deliv...  Positive
# 5    gregabbott_tx tedcruz on my first day i will...  Positive
# 6    warriorwoman91 i liked her and was happy whe...  Negative

# %%
df = df[df.sentiment != "Neutral"]

n = df.size - df[df['sentiment'] == 'Positive'].size - df[df['sentiment'] == 'Negative'].size

print(n)
# Out:
# 0

# %% [markdown]
# This check above ensures that we only have tweets labelled positive and negative in our dataset.

# %%
  max_features = 2000

# Initialising a special Tokenizer class object to tokenize our data (tweets). This will only "remember" max_features-1 words.
tokenizer = Tokenizer(num_words=max_features, split=' ')

# Fitting our internal vocabulary on our tweets, using the fit_on_texts method of the Tokenizer class.
tokenizer.fit_on_texts(df['text'].values)
X = tokenizer.texts_to_sequences(df['text'].values)
X = pad_sequences(X)
X.shape
# Out:
# (10729, 28)

# %%
vocabSize = len(tokenizer.word_index) + 1
print(vocabSize)
# Out:
# 15793

# %% [markdown]
# #### Hyperparameter tuning:
#
# The variables embedDim, lstmOutDim, batchSize, and dropout are the hyperparameters in this experiment. These are the values that influence the derived parameters' values.

# %% [markdown]
# We use the softmax function

# %%
embedDim=128
lstmOutDim=196
model = Sequential()                                                                
# Each layer has one input tensor and one output tensor.
model.add(Embedding(max_features, embedDim, input_length = X.shape[1]))

# drops out (disregards) 1D feature map instead of individual elements.
model.add(SpatialDropout1D(0.4))

# Creating an LSTM layer, keeping dropout low as we have a SpatialDropout layer already.
model.add(LSTM(lstmOutDim, dropout=0.2))

# Output layer with 2 nodes.
model.add(Dense(2, activation='softmax'))

# Now, we compile the model and get it ready for training, we use the Adam optimizer with bce loss.
bce = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=bce, metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 28, 128)           256000
#
#  spatial_dropout1d (SpatialD  (None, 28, 128)          0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 196)               254800
#
#  dense (Dense)               (None, 2)                 394
#
# =================================================================
# Total params: 511,194
# Trainable params: 511,194
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Splitting the dataset into training and testing datasets:

# %%
# One hot encoding the labels
Y = pd.get_dummies(df['sentiment']).values


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.35, random_state = 26)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (6973, 28) (6973, 2)
# (3756, 28) (3756, 2)

# %% [markdown]
# #### "Fitting" (Training) the model:

# %%
model.fit(X_train, Y_train, epochs = 10,  verbose = 2)
# Out:
# Epoch 1/10
# 218/218 - 11s - loss: 0.4525 - accuracy: 0.8128 - 11s/epoch - 50ms/step
# Epoch 2/10
# 218/218 - 9s - loss: 0.3316 - accuracy: 0.8642 - 9s/epoch - 41ms/step
# Epoch 3/10
# 218/218 - 9s - loss: 0.2824 - accuracy: 0.8838 - 9s/epoch - 42ms/step
# Epoch 4/10
# 218/218 - 9s - loss: 0.2519 - accuracy: 0.8952 - 9s/epoch - 40ms/step
# Epoch 5/10
# 218/218 - 8s - loss: 0.2230 - accuracy: 0.9085 - 8s/epoch - 37ms/step
# Epoch 6/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6764/3909319676.py in <module>
# ----> 1 model.fit(X_train, Y_train, epochs = 10,  verbose = 2)
#
# c:\Users\kannu\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\kannu\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# c:\Users\kannu\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\kannu\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\kannu\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\kannu\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# c:\Users\kannu\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\kannu\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# c:\Users\kannu\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Setting aside a validation set to check accuracy.

# %%
validation_size = 1500
batch_size = 32

X_validate = X_test[-validation_size:]
Y_validate = Y_test[-validation_size:]
X_test = X_test[:-validation_size]
Y_test = Y_test[:-validation_size]
score, acc = model.evaluate(X_test, Y_test, verbose=2, batch_size=batch_size)

print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
# Out:
# 71/71 - 2s - loss: 0.3944 - accuracy: 0.8493 - 2s/epoch - 35ms/step
# score: 0.39
# acc: 0.85

# %%
X_test.shape
# Out:
# (3756, 28)

# %% [markdown]
# #### Calculating Accuracy of the model.

# %%
posCount, negCount, posCorrect, negCorrect = 0, 0, 0, 0

for x in range(len(X_validate)):
    
    result = model.predict(X_validate[x].reshape(1, X_test.shape[1]), batch_size=1, verbose=2)[0]
    if np.argmax(result) == np.argmax(Y_validate[x]):
        if np.argmax(Y_validate[x]) == 0:
            negCorrect += 1
        else:
            posCorrect += 1
       
    if np.argmax(Y_validate[x]) == 0:
        negCount += 1
    else:
        posCount += 1


# bce()
print("Positive Accuracy: %.3f" % (posCorrect/posCount*100), "%")
print("Negative Accuracy: %.3f" % (negCorrect/negCount*100), "%")
# Out:
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 64ms/epoch - 64ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 34ms/epoch - 34ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 61ms/epoch - 61ms/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - 108ms/epoch - 108ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 34ms/epoch - 34ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 59ms/epoch - 59ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 51ms/epoch - 51ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 16ms/epoch - 16ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 34ms/epoch - 34ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 34ms/epoch - 34ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 34ms/epoch - 34ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 16ms/epoch - 16ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 16ms/epoch - 16ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 34ms/epoch - 34ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 16ms/epoch - 16ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 31ms/epoch - 31ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 24ms/epoch - 24ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 22ms/epoch - 22ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 16ms/epoch - 16ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 30ms/epoch - 30ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 28ms/epoch - 28ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 19ms/epoch - 19ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 21ms/epoch - 21ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 17ms/epoch - 17ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - 18ms/epoch - 18ms/step
# 1/1 - 0s - 20ms/epoch - 20ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 23ms/epoch - 23ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 25ms/epoch - 25ms/step
# 1/1 - 0s - 26ms/epoch - 26ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 27ms/epoch - 27ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - 35ms/epoch - 35ms/step
# 1/1 - 0s - 29ms/epoch - 29ms/step
# 1/1 - 0s - 32ms/epoch - 32ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# Positive Accuracy 60.510 %
# Negative Accuracy 92.496 %
